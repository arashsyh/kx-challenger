# %%
import pandas as pd

# %%
train_data = pd.read_csv('train_w_weight.csv')
# Removing index and name columns
train_data = train_data.drop(['EmployeeID', 'Name'], axis=1)

# %%
train_data.head()
# Out:
#    Age Attrition     BusinessTravel   DailyRate              Department  \
# 0   41       Yes      Travel_Rarely  363.779528                   Sales
# 1   49        No  Travel_Frequently  256.667244  Research & Development
# 2   37       Yes      Travel_Rarely  214.151811  Research & Development
# 3   33        No  Travel_Frequently  250.368661  Research & Development
# 4   27        No      Travel_Rarely  226.748976  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0  ...                         1           160                 0
# 1  ...                         4           160                 1
# 2  ...                         2           160                 0
# 3  ...                         3           160                 0
# 4  ...                         4           160                 1
#
#    TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0               1               6
# 1                 10                      3               3              10
# 2                  7                      3               3               0
# 3                  8                      3               3               8
# 4                  6                      3               3               2
#
#   YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  4                        0                     5
# 1                  7                        1                     7
# 2                  0                        0                     0
# 3                  7                        3                     0
# 4                  2                        2                     2
#
# [5 rows x 35 columns]

# %%
train_data.loc[train_data['Attrition'] == 'No']
# Out:
#      Age Attrition     BusinessTravel   DailyRate              Department  \
# 1     49        No  Travel_Frequently  256.667244  Research & Development
# 3     33        No  Travel_Frequently  250.368661  Research & Development
# 4     27        No      Travel_Rarely  226.748976  Research & Development
# 5     32        No  Travel_Frequently  226.748976  Research & Development
# 6     59        No      Travel_Rarely  234.622205  Research & Development
# ..   ...       ...                ...         ...                     ...
# 993   25        No      Travel_Rarely  321.259842                   Sales
# 994   52        No  Travel_Frequently  465.721417  Research & Development
# 995   43        No      Travel_Rarely  251.943307  Research & Development
# 996   27        No      Travel_Rarely  349.606299                   Sales
# 998   26        No      Travel_Rarely  196.830709  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# 1                   8          1  Life Sciences              1
# 3                   3          4  Life Sciences              1
# 4                   2          1        Medical              1
# 5                   2          2  Life Sciences              1
# 6                   3          3        Medical              1
# ..                ...        ...            ...            ...
# 993                18          1  Life Sciences              1
# 994                28          2        Medical              1
# 995                 6          3        Medical              1
# 996                10          3      Marketing              1
# 998                 2          1        Medical              1
#
#      EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 1                 2  ...                         4           160
# 3                 5  ...                         3           160
# 4                 7  ...                         4           160
# 5                 8  ...                         3           160
# 6                10  ...                         1           160
# ..              ...  ...                       ...           ...
# 993            1399  ...                         2           160
# 994            1401  ...                         2           160
# 995            1402  ...                         1           160
# 996            1403  ...                         4           160
# 998            1407  ...                         4           160
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1                   1                 10                      3
# 3                   0                  8                      3
# 4                   1                  6                      3
# 5                   0                  8                      2
# 6                   3                 12                      3
# ..                ...                ...                    ...
# 993                 0                  6                      3
# 994                 1                 24                      3
# 995                 0                 20                      3
# 996                 0                  6                      3
# 998                 0                  5                      2
#
#     WorkLifeBalance  YearsAtCompany YearsInCurrentRole  \
# 1                 3              10                  7
# 3                 3               8                  7
# 4                 3               2                  2
# 5                 2               7                  7
# 6                 2               1                  0
# ..              ...             ...                ...
# 993               2               3                  2
# 994               2               5                  3
# 995               1              20                  7
# 996               3               6                  2
# 998               3               4                  3
#
#      YearsSinceLastPromotion  YearsWithCurrManager
# 1                          1                     7
# 3                          3                     0
# 4                          2                     2
# 5                          3                     6
# 6                          0                     0
# ..                       ...                   ...
# 993                        1                     2
# 994                        0                     2
# 995                        1                     8
# 996                        4                     4
# 998                        1                     1
#
# [832 rows x 35 columns]
